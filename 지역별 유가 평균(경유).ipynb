# %%
# !pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

file_path = "C:/Users/Playdata/Desktop/class/SKN06-1st-5Team/주유소_지역별_평균판매가격(경유).csv"  # 파일 경로를 설정합니다.
df = pd.read_csv(file_path, encoding='euc-kr')
print(df)
# Out:
#                구분       서울       부산       대구       인천       광주       대전  \
# 0     2019년09월01일  1474.48  1351.58  1337.14  1356.94  1339.32  1371.00
# 1     2019년09월02일  1479.77  1356.61  1339.91  1361.09  1345.14  1375.82
# 2     2019년09월03일  1481.44  1361.67  1342.08  1362.84  1349.11  1377.37
# 3     2019년09월04일  1482.35  1362.04  1342.31  1366.89  1349.57  1377.87
# 4     2019년09월05일  1482.82  1362.22  1341.83  1368.04  1349.89  1376.72
# ...           ...      ...      ...      ...      ...      ...      ...
# 1862  2024년10월06일  1499.89  1391.65  1374.17  1409.14  1387.76  1409.91
# 1863  2024년10월07일  1503.63  1390.98  1374.46  1408.29  1388.33  1410.26
# 1864  2024년10월08일  1506.38  1391.00  1375.03  1410.42  1389.81  1411.96
# 1865  2024년10월09일  1509.05  1391.05  1375.22  1410.45  1390.84  1413.57
# 1866  2024년10월10일  1510.77  1392.30  1375.84  1411.94  1391.24  1414.51
#
#            울산       경기       강원       충북       충남       전북       전남       경북  \
# ...

# %%
print("데이터프레임 헤더:")
print(df.columns)
# Out:
# 데이터프레임 헤더:
# Index(['구분', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남',
#        '전북', '전남', '경북', '경남', '제주', '세종'],
#       dtype='object')

# %%
# CSV 파일 경로
file_path = "C:/Users/Playdata/Desktop/class/SKN06-1st-5Team/주유소_지역별_평균판매가격(경유).csv"
df = pd.read_csv(file_path, encoding='euc-kr')

# 년도별 평균 가격 계산
df['연도'] = df['구분'].str[:4]  # '구분' 열에서 연도 추출
average_prices = df.groupby('연도').mean(numeric_only=True)
print(average_prices)
# Out:
#                서울           부산           대구           인천           광주  \
# 연도
# 2019  1478.837049  1364.504180  1353.829918  1375.859016  1364.457049
# 2020  1286.436612  1169.558689  1156.783087  1186.048607  1171.893579
# 2021  1473.514082  1378.156767  1368.707041  1393.677890  1380.041123
# 2022  1910.608466  1820.016000  1809.027589  1839.136904  1825.736548
# 2023  1651.421808  1535.476795  1518.956000  1544.815562  1536.632274
# 2024  1602.119437  1492.783592  1474.899049  1508.670775  1493.873873
#
#                대전           울산           경기           강원           충북  \
# 연도
# 2019  1384.708689  1371.218607  1386.592377  1400.060000  1385.088852
# 2020  1173.824536  1175.718552  1193.639563  1205.778743  1193.476230
# 2021  1386.643452  1379.384685  1398.491479  1397.993753  1394.384274
# 2022  1839.774849  1822.613315  1845.888301  1859.078082  1848.529973
# 2023  1555.420822  1532.781644  1558.797973  1579.059753  1563.417918
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -------- ------------------------------- 1.6/7.8 MB 8.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/7.8 MB 8.4 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/7.8 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 8.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------------------------- ------ 1.8/2.2 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 9.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt

# 지역 이름 영어 변경
region_mapping = {
    '서울': 'Seoul',
    '부산': 'Busan',
    '대구': 'Daegu',
    '인천': 'Incheon',
    '광주': 'Gwangju',
    '대전': 'Daejeon',
    '울산': 'Ulsan',
    '경기': 'Gyeonggi',
    '강원': 'Gangwon',
    '충북': 'Chungbuk',
    '충남': 'Chungnam',
    '전북': 'Jeonbuk',
    '전남': 'Jeonnam',
    '경북': 'Gyeongbuk',
    '경남': 'Gyeongnam',
    '제주': 'Jeju',
    '세종': 'Sejong'
}
average_prices.columns = average_prices.columns.map(region_mapping)
# NaN 값이 포함된 열 제거
average_prices = average_prices.loc[:, average_prices.columns.notnull()]

# 그래프 색상 변경
colors = {
    'Seoul': 'blue',
    'Busan': 'orange',
    'Daegu': 'green',
    'Incheon': 'red',
    'Gwangju': 'purple',
    'Daejeon': 'brown',
    'Ulsan': 'pink',
    'Gyeonggi': 'gray',
    'Gangwon': 'cyan',
    'Chungbuk': 'magenta',
    'Chungnam': 'yellow',
    'Jeonbuk': 'teal',
    'Jeonnam': 'navy',
    'Gyeongbuk': 'olive',
    'Gyeongnam': 'gold',
    'Jeju': 'lime',
    'Sejong': 'coral'
}

# 그래프
plt.figure(figsize=(12, 6))  # 크기 설정

for column in average_prices.columns:
    if column in colors:  # 색상 딕셔너리에 있는 경우만 그리기
        plt.plot(average_prices.index, average_prices[column], marker='o', color=colors[column], label=column)

plt.title('Diesel Annual Average Prices by Region', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.legend()
plt.xticks(rotation=45)  # x축 레이블 회전
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

# 연도별 특정 월 데이터를 조회하고 그래프를 그리는 함수
def plot_monthly_prices(month, df, region_mapping):
    selected_month = f"{month:02d}월"  # 입력된 달을 '월' 형식으로 변환 (예: '09월')
    monthly_prices = df[df['연도/월'].str.endswith(selected_month)].set_index('연도/월')
    average_prices = monthly_prices.groupby('연도/월').mean(numeric_only=True)
    average_prices.columns = average_prices.columns.map(region_mapping)

    colors = {
        'Seoul': 'blue',
        'Busan': 'orange',
        'Daegu': 'green',
        'Incheon': 'red',
        'Gwangju': 'purple',
        'Daejeon': 'brown',
        'Ulsan': 'pink',
        'Gyeonggi': 'gray',
        'Gangwon': 'cyan',
        'Chungbuk': 'magenta',
        'Chungnam': 'yellow',
        'Jeonbuk': 'teal',
        'Jeonnam': 'navy',
        'Gyeongbuk': 'olive',
        'Gyeongnam': 'gold',
        'Jeju': 'lime',
        'Sejong': 'coral'
    }

    plt.figure(figsize=(12, 6))  # 크기 설정
    
    for column in average_prices.columns:
        if column in colors:
            plt.plot(average_prices.index, average_prices[column], marker='o', color=colors[column], label=column)

    plt.title(f'Diesel Prices by Region for {selected_month}', fontsize=16)
    plt.xlabel('Year', fontsize=14)
    plt.ylabel('Price (₩)', fontsize=14)
    plt.legend()
    plt.xticks(rotation=45)  # x축 레이블 회전
    plt.grid()
    plt.show()

# CSV 파일 경로 설정 및 데이터 로드
file_path = "C:/Users/Playdata/Desktop/class/SKN06-1st-5Team/주유소_지역별_평균판매가격(경유).csv"
df = pd.read_csv(file_path, encoding='euc-kr')

# '구분' 열에서 연도/월 정보 추출
df['연도/월'] = df['구분'].str[:8]

# 지역 이름 영어 변경 매핑
region_mapping = {
    '서울': 'Seoul',
    '부산': 'Busan',
    '대구': 'Daegu',
    '인천': 'Incheon',
    '광주': 'Gwangju',
    '대전': 'Daejeon',
    '울산': 'Ulsan',
    '경기': 'Gyeonggi',
    '강원': 'Gangwon',
    '충북': 'Chungbuk',
    '충남': 'Chungnam',
    '전북': 'Jeonbuk',
    '전남': 'Jeonnam',
    '경북': 'Gyeongbuk',
    '경남': 'Gyeongnam',
    '제주': 'Jeju',
    '세종': 'Sejong'
}
month = 7 #사용자 원하는 달 조회
plot_monthly_prices(month, df, region_mapping)
# Out:
# C:\Users\Playdata\miniconda3\envs\python\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Playdata\miniconda3\envs\python\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# CSV 파일 경로 설정 및 데이터 로드
file_path = "C:/Users/Playdata/Desktop/class/SKN06-1st-5Team/주유소_지역별_평균판매가격(경유).csv"
df = pd.read_csv(file_path, encoding='euc-kr')

# '구분' 열에서 연도/월 정보 추출
df['연도/월'] = df['구분'].str[:8]

# 지역 이름 영어 변경 매핑
region_mapping = {
    '서울': 'Seoul',
    '부산': 'Busan',
    '대구': 'Daegu',
    '인천': 'Incheon',
    '광주': 'Gwangju',
    '대전': 'Daejeon',
    '울산': 'Ulsan',
    '경기': 'Gyeonggi',
    '강원': 'Gangwon',
    '충북': 'Chungbuk',
    '충남': 'Chungnam',
    '전북': 'Jeonbuk',
    '전남': 'Jeonnam',
    '경북': 'Gyeongbuk',
    '경남': 'Gyeongnam',
    '제주': 'Jeju',
    '세종': 'Sejong'
}

# 연도별 특정 월 데이터를 조회하고 그래프를 그리는 함수
def plot_monthly_prices(month, df, region_mapping):
    # 사용자가 입력한 달에 해당하는 데이터만 필터링
    selected_month = f"{month:02d}월"  # 입력된 달을 '월' 형식으로 변환 (예: '09월')

    # 해당 달의 데이터를 추출
    monthly_prices = df[df['연도/월'].str.endswith(selected_month)].set_index('연도/월')

    # 연도별 데이터를 계산 (매년 해당 월의 평균 값)
    average_prices = monthly_prices.groupby('연도/월').mean(numeric_only=True)

    # 데이터프레임의 컬럼을 영어로 변환
    average_prices.columns = average_prices.columns.map(region_mapping)

    # 그래프 색상 설정
    colors = {
        'Seoul': 'blue',
        'Busan': 'orange',
        'Daegu': 'green',
        'Incheon': 'red',
        'Gwangju': 'purple',
        'Daejeon': 'brown',
        'Ulsan': 'pink',
        'Gyeonggi': 'gray',
        'Gangwon': 'cyan',
        'Chungbuk': 'magenta',
        'Chungnam': 'yellow',
        'Jeonbuk': 'teal',
        'Jeonnam': 'navy',
        'Gyeongbuk': 'olive',
        'Gyeongnam': 'gold',
        'Jeju': 'lime',
        'Sejong': 'coral'
    }

    # 그래프 그리기
    plt.figure(figsize=(12, 6))  # 크기 설정

    for column in average_prices.columns:
        if column in colors:  # 색상 딕셔너리에 있는 경우만 그리기
            plt.plot(average_prices.index, average_prices[column], marker='o', color=colors[column], label=column)

    plt.title(f'Diesel Prices by Region for {selected_month} (Yearly Comparison)', fontsize=16)
    plt.xlabel('Year', fontsize=14)
    plt.ylabel('Price (₩)', fontsize=14)
    plt.legend()
    plt.xticks(rotation=45)  # x축 레이블 회전
    plt.grid()

    # 그래프를 Streamlit에 표시
    st.pyplot(plt)

# Streamlit 웹 페이지 설정
st.title('Monthly Diesel Price Visualization')
st.write('Select the month to visualize the yearly diesel price trend.')

# 사용자가 조회할 월을 선택할 수 있도록 옵션 제공
selected_month = st.selectbox('Select a month:', list(range(1, 13)))

# 선택한 달에 대해 그래프 그리기
plot_monthly_prices(selected_month, df, region_mapping)
# Out:
# 2024-10-14 13:44:54.614 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-14 13:44:54.741
# ...
#   command:
#
#     streamlit run C:\Users\Playdata\miniconda3\envs\python\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-10-14 13:44:54.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-14 13:44:54.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-14 13:44:54.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-14 13:44:54.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-14 13:44:54.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 파일 경로 설정
file_path = "C:/Users/Playdata/Desktop/class/SKN06-1st-5Team/주유소_지역별_평균판매가격(경유).csv"
df = pd.read_csv(file_path, encoding='euc-kr')

# '구분' 열에서 연도와 월 정보 추출
df['연도'] = df['구분'].str[:4]  # '구분' 열에서 연도 추출
df['월'] = df['구분'].str[5:7]  # '구분' 열에서 월 추출

# 사용자가 조회할 특정 월을 입력
month = '10' 

# 특정 월에 해당하는 데이터 필터링
df_month = df[df['월'] == month]

# 연도별 특정 월의 평균 가격 계산
average_prices_month = df_month.groupby('연도').mean(numeric_only=True)

# 지역 이름 영어 변경
region_mapping = {
    '서울': 'Seoul',
    '부산': 'Busan',
    '대구': 'Daegu',
    '인천': 'Incheon',
    '광주': 'Gwangju',
    '대전': 'Daejeon',
    '울산': 'Ulsan',
    '경기': 'Gyeonggi',
    '강원': 'Gangwon',
    '충북': 'Chungbuk',
    '충남': 'Chungnam',
    '전북': 'Jeonbuk',
    '전남': 'Jeonnam',
    '경북': 'Gyeongbuk',
    '경남': 'Gyeongnam',
    '제주': 'Jeju',
    '세종': 'Sejong'
}

# 영어로 지역 이름 매핑
average_prices_month.columns = average_prices_month.columns.map(region_mapping)
# NaN 값이 포함된 열 제거
average_prices_month = average_prices_month.loc[:, average_prices_month.columns.notnull()]

# 그래프 색상 설정
colors = {
    'Seoul': 'blue',
    'Busan': 'orange',
    'Daegu': 'green',
    'Incheon': 'red',
    'Gwangju': 'purple',
    'Daejeon': 'brown',
    'Ulsan': 'pink',
    'Gyeonggi': 'gray',
    'Gangwon': 'cyan',
    'Chungbuk': 'magenta',
    'Chungnam': 'yellow',
    'Jeonbuk': 'teal',
    'Jeonnam': 'navy',
    'Gyeongbuk': 'olive',
    'Gyeongnam': 'gold',
    'Jeju': 'lime',
    'Sejong': 'coral'
}

# 그래프 그리기
plt.figure(figsize=(12, 6))

for column in average_prices_month.columns:
    if column in colors:
        plt.plot(average_prices_month.index, average_prices_month[column], marker='o', color=colors[column], label=column)

plt.title(f'Diesel Average Prices by Region for {month}월', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Price (₩)', fontsize=14)
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# C:\Users\Playdata\miniconda3\envs\python\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 파일 경로 설정
file_path = "C:/Users/Playdata/Desktop/class/SKN06-1st-5Team/주유소_지역별_평균판매가격(경유).csv"
df = pd.read_csv(file_path, encoding='euc-kr')

# '구분' 열에서 연도와 월 정보 추출
df['연도'] = df['구분'].str[:4]  # '구분' 열에서 연도 추출
df['월'] = df['구분'].str[5:7]  # '구분' 열에서 월 추출

# 사용자가 조회할 특정 월을 입력
month = '09'  # 예: 9월 (문자열로 처리)

# 특정 월에 해당하는 데이터 필터링
df_month = df[df['월'] == month]

# 연도별 특정 월의 평균 가격 계산
average_prices_month = df_month.groupby('연도').mean(numeric_only=True)

# 지역 이름 영어 변경
region_mapping = {
    '서울': 'Seoul',
    '부산': 'Busan',
    '대구': 'Daegu',
    '인천': 'Incheon',
    '광주': 'Gwangju',
    '대전': 'Daejeon',
    '울산': 'Ulsan',
    '경기': 'Gyeonggi',
    '강원': 'Gangwon',
    '충북': 'Chungbuk',
    '충남': 'Chungnam',
    '전북': 'Jeonbuk',
    '전남': 'Jeonnam',
    '경북': 'Gyeongbuk',
    '경남': 'Gyeongnam',
    '제주': 'Jeju',
    '세종': 'Sejong'
}

# 영어로 지역 이름 매핑
average_prices_month.columns = average_prices_month.columns.map(region_mapping)
# NaN 값이 포함된 열 제거
average_prices_month = average_prices_month.loc[:, average_prices_month.columns.notnull()]

# 그래프 색상 설정
colors = {
    'Seoul': 'blue',
    'Busan': 'orange',
    'Daegu': 'green',
    'Incheon': 'red',
    'Gwangju': 'purple',
    'Daejeon': 'brown',
    'Ulsan': 'pink',
    'Gyeonggi': 'gray',
    'Gangwon': 'cyan',
    'Chungbuk': 'magenta',
    'Chungnam': 'yellow',
    'Jeonbuk': 'teal',
    'Jeonnam': 'navy',
    'Gyeongbuk': 'olive',
    'Gyeongnam': 'gold',
    'Jeju': 'lime',
    'Sejong': 'coral'
}

# 그래프 그리기
plt.figure(figsize=(12, 6))

for column in average_prices_month.columns:
    if column in colors:
        plt.plot(average_prices_month.index, average_prices_month[column], marker='o', color=colors[column], label=column)

plt.title(f'Diesel Average Prices by Region for {month}월', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Price (₩)', fontsize=14)
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()
